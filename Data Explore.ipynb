# %%
# %load_ext google.cloud.bigquery

# %%
# %%bigquery trouble_ticket_repeat
# SELECT * FROM `dac-truck-rolls-pr-57e5f4.dac_truck_rolls_pr_dataset.trouble_ticket_repeat_orc` LIMIT 1000
# Out:
# Query complete after 0.05s: 100% 1/1 [00:00<00:00, 216.58query/s]
# Downloading: 100% 1000/1000 [00:00<00:00, 1325.67rows/s]

# %%
# %%bigquery insights
# SELECT * FROM `dac-truck-rolls-pr-57e5f4.dac_truck_rolls_pr_dataset.tbl_insights_allup` LIMIT 1000
# Out:
# Query complete after 0.00s: 100% 1/1 [00:00<00:00, 413.88query/s]
# Downloading: 100% 1000/1000 [00:00<00:00, 1430.42rows/s]

# %%
# %%bigquery customer_fact
# SELECT * FROM `dac-truck-rolls-pr-57e5f4.dac_truck_rolls_pr_dataset.fact_cust_hs_tv_omnisci` LIMIT 1000
# Out:
# Query complete after 0.01s: 100% 1/1 [00:00<00:00, 136.34query/s]
# Downloading: 100% 1000/1000 [00:00<00:00, 1181.89rows/s]

# %%
# %%bigquery dart_fielded_jobs_journey
# SELECT * FROM `dac-truck-rolls-pr-57e5f4.dac_truck_rolls_pr_dataset.wrk_dart_fielded_jobs_journeys_orc_20220428` LIMIT 1000
# Out:
# Query complete after 0.00s: 100% 1/1 [00:00<00:00, 450.85query/s]
# Downloading: 100% 1000/1000 [00:00<00:00, 1617.16rows/s]

# %% [markdown]
# # Trouble Ticket Repeat

# %%
# %%bigquery trouble_ticket_repeat
# SELECT
#     trouble_ticket_key_id,
#     bus_service_address_id,
#     tt_type_cd,
#     tt_cct_level_1_cd,
#     tt_cct_level_2_cd,
#     tt_cct_level_3_cd,
#     tt_resolution_level_1_cd,
#     tt_resolution_level_2_cd,
#     tt_resolution_level_3_cd,
#     tt_agent_id_str,
#     prim_work_order_id,
#     prim_wo_status_desc_txt,
#     wo_job_type_list_str,
#     wo_prim_team_member_id,
#     wo_team_member_list_str,
#     wo_contracting_co_nm,
#     wo_service_area_clli_cd,
#     wo_service_area_nm,
#     wo_region_nm,
#     gateway_prior_product_nm,
#     ttv_stb_prior_model_str,
#     # prev,
#     prev_wo_request_create_utc_ts,
#     prev_wo_trouble_ticket_key_id,
#     next_wo_trouble_ticket_key_id,
#     create_ts,
#     last_updt_ts
# FROM `dac-truck-rolls-pr-57e5f4.dac_truck_rolls_pr_dataset.trouble_ticket_repeat_orc` LIMIT 1000000
# Out:
# Query complete after 0.00s: 100% 3/3 [00:00<00:00, 1120.87query/s]
# Downloading: 100% 1000000/1000000 [00:01<00:00, 527646.67rows/s]

# %%
trouble_ticket_repeat.head()
# Out:
#   trouble_ticket_key_id bus_service_address_id   tt_type_cd tt_cct_level_1_cd  \
# 0            1049530084            AB003037899   CABLE/DROP              Drop
# 1            1049518329            BC005523252        BASIC      No Dial Tone
# 2            1054581027            AB001602560         HSIA      Troubleshoot
# 3            1049250253            AB000854303        BASIC      No Dial Tone
# 4            1051696870            AB001708455  CUSTOM CALL        VOICE MAIL
#
#          tt_cct_level_2_cd  tt_cct_level_3_cd    tt_resolution_level_1_cd  \
# 0    Low-Cut Not Hazardous                                        Test OK
# 1        Incoming OK? - No                     Subscriber Carrier Systems
# 2                  No Sync  Previously Worked                     Exclude
# 3        Incoming OK? - No                                        Exclude
# 4  Unable to leave message                                        Test OK
#
# ...

# %% [markdown]
# # Insights

# %%
# %%bigquery insights
# SELECT
#     call_convrstn_dt,
#     topic,
#     smart_highlight,
#     custom_highlight,
#     ivr_session_id,
#     ava_speech_topic,
#     ivr_ava,
#     cust_id,
#     convrstn_transcript_txt,
#     call_convrstn_id,
#     tot_durtn_min_qty,
#     agnt_sntmnt_mgntd_qty,
#     clnt_sntmnt_scor_qty,
#     clnt_sntmnt_mgntd_qty,
#     convrstn_turn_cnt,
#     datetime_pst,
#     datetime_est,
#     datetime_mst,
#     agnt_id,
#     report_session_id,
#     utn,
#     ani
# FROM `dac-truck-rolls-pr-57e5f4.dac_truck_rolls_pr_dataset.tbl_insights_allup` LIMIT 1000000
# Out:
# Query complete after 0.00s: 100% 5/5 [00:00<00:00, 2228.88query/s]
# Downloading: 100% 1000000/1000000 [00:08<00:00, 112383.59rows/s]

# %%
insights.head()
# Out:
#   call_convrstn_dt                                              topic  \
# 0       2022-06-06                                               None
# 1       2022-02-10  data_flow_issue,troubleshoot_tv_box,troublesho...
# 2       2022-01-18                           troubleshoot_internet_tv
# 3       2021-10-16                                needs_clarification
# 4       2022-07-18            troubleshoot_internet_tv,cancel_service
#
#                             smart_highlight  \
# 0                    CONFIRM_ISSUE_RESOLVED
# 1                                      None
# 2  CHECK_ISSUE_RESOLVED,AUTHENTICATION_INFO
# 3                                      None
# 4                                      None
#
#                                     custom_highlight ivr_session_id  \
# 0                                               None           None
# 1                                               None           None
# ...

# %% [markdown]
# # Customer Fact

# %%
# %%bigquery customer_fact
# SELECT
#     cust_id_fms_address_key,
#     cust_id,
#     fms_address,
#     postal_code,
#     latitude,
#     longitude,
#     iptv_tenure_days,
#     hsia_tenure_days,
#     voice_tenure_days,
#     stv_tenure_days,
#     voice_curr_charge_amt,
#     hsia_curr_charge_amt,
#     iptv_curr_charge_amt,
#     total_curr_charge_amt,
#     gw_software_version,
#     netflix_app_hits,
#     youtube_app_hits,
#     total_curr_charge_before_tax_amt,
#     total_curr_charge_tax_amt,
#     max_bill_dt,
# FROM `dac-truck-rolls-pr-57e5f4.dac_truck_rolls_pr_dataset.fact_cust_hs_tv_omnisci` LIMIT 1000000
# Out:
# Query complete after 0.00s: 100% 3/3 [00:00<00:00, 981.20query/s]
# Downloading: 100% 1000000/1000000 [00:02<00:00, 453413.61rows/s]

# %%
customer_fact.head()
# Out:
#   cust_id_fms_address_key   cust_id  fms_address postal_code   latitude  \
# 0     1561602|AB001625383   1561602  AB001625383      T5G1G4  53.578672
# 1    46392062|BC005337775  46392062  BC005337775      V6E4P2  49.277379
# 2    84631229|AB003122597  84631229  AB003122597        None  57.337594
# 3    92470239|BC006081438  92470239  BC006081438        None  49.116869
# 4    76925695|AB000802721  76925695  AB000802721      T1P1H3  51.050550
#
#     longitude  iptv_tenure_days  hsia_tenure_days  voice_tenure_days  \
# 0 -113.484682               314               314                930
# 1 -123.132421              3425              3425               <NA>
# 2 -111.782384              1662              1662               <NA>
# 3 -122.815073               292               292                292
# 4 -113.386260              1181              1181               1181
#
#    stv_tenure_days voice_curr_charge_amt hsia_curr_charge_amt  \
# ...

# %% [markdown]
# # Journey Table

# %%
# %%bigquery dart_fielded_jobs_journey
# SELECT
#     journey_id,
#     enterprise_customer_id,
#     work_order_classification_cd,
#     technology_list,
#     product_list,
#     journey_job_ids,
#     journey_statuses,
#     journey_ir_truck_rolls,
#     journey_ca_truck_rolls,
#     journey_pre_dispatch_cancels,
# FROM `dac-truck-rolls-pr-57e5f4.dac_truck_rolls_pr_dataset.wrk_dart_fielded_jobs_journeys_orc_20220428` LIMIT 1000
# Out:
# Query complete after 0.00s: 100% 2/2 [00:00<00:00, 740.45query/s]
# Downloading: 100% 1000/1000 [00:00<00:00, 1364.21rows/s]

# %%
dart_fielded_jobs_journey.head()
# Out:
#            journey_id enterprise_customer_id work_order_classification_cd  \
# 0  38088124.000000000               99775688                        ORDER
# 1  38100564.000000000               91533133                      TROUBLE
# 2  42588231.000000000               75609463                      TROUBLE
# 3  43058401.000000000               87816914                      TROUBLE
# 4  42007326.000000000               57372676                      TROUBLE
#
#   technology_list product_list journey_job_ids journey_statuses  \
# 0            None         None
# 1            None         None
# 2   COPPER_BONDED           HS        42588231   CUST_NOT_READY
# 3            GPON           HS        43058401   CUST_NOT_READY
# 4            GPON           HS        42007326      CUST_CANCEL
#
#    journey_ir_truck_rolls  journey_ca_truck_rolls  \
# 0                       0                       0
# 1                       0                       0
# ...
